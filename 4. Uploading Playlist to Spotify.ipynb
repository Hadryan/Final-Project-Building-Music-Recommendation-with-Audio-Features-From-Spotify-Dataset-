# %%
import pandas as pd
import json
import requests

# %%
import ast

# %%
TOKEN = 'BQCy0MdxgUMGZ4TNhTNPnTGpDK5l7ckrwDD809OIs096IIfiFXxG1sJUPuRqn4GX-kWDYACL5Gn-UMgufnypESpRFNaNalKsfFSlBHPPGFH8W0q0JLs-E3jLB2ww2JWMLji30GjElMWtDg375CVZnL2vCUW5IC23S2xnJjk3O1Lc2PMZLyV2pHn8'

# %% [markdown]
# # Making the playlist

# %%
url = "https://api.spotify.com/v1/users/ramzjet/playlists"
headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
data = ("{\"name\": \"Playlist From Final Project 1\"}")
r = requests.post(url, headers=headers, data = data)
parsed = json.loads(r.text)

# %%
playlist1 = [parsed]

# %%
url = "https://api.spotify.com/v1/users/ramzjet/playlists"
headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
data = ("{\"name\": \"Playlist From Final Project 2\"}")
r = requests.post(url, headers=headers, data = data)
parsed = json.loads(r.text)
playlist2 = [parsed]

# %%
playlist2
# Out:
# [{'collaborative': False,
#   'description': None,
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/0vcZPqe7JOKqWOkRi62vid'},
#   'followers': {'href': None, 'total': 0},
#   'href': 'https://api.spotify.com/v1/playlists/0vcZPqe7JOKqWOkRi62vid',
#   'id': '0vcZPqe7JOKqWOkRi62vid',
#   'images': [],
#   'name': 'Playlist From Final Project 2',
#   'owner': {'display_name': 'Muhammad Ramzy',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/ramzjet'},
#    'href': 'https://api.spotify.com/v1/users/ramzjet',
#    'id': 'ramzjet',
#    'type': 'user',
#    'uri': 'spotify:user:ramzjet'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MSxlM2E0YmZlMTJhMzVjMDJhMzRkNTAxY2I2ZGRlNmU1NzFhYmYyN2Q0',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/0vcZPqe7JOKqWOkRi62vid/tracks',
#    'items': [],
#    'limit': 100,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 0},
#   'type': 'playlist',
# ...

# %%
url = "https://api.spotify.com/v1/users/ramzjet/playlists"
headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
data = ("{\"name\": \"Playlist From Final Project 3\"}")
r = requests.post(url, headers=headers, data = data)
parsed = json.loads(r.text)
playlist3 = [parsed]

# %%
playlist3
# Out:
# [{'collaborative': False,
#   'description': None,
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/2yoeICv7TkSqnh220UMwIE'},
#   'followers': {'href': None, 'total': 0},
#   'href': 'https://api.spotify.com/v1/playlists/2yoeICv7TkSqnh220UMwIE',
#   'id': '2yoeICv7TkSqnh220UMwIE',
#   'images': [],
#   'name': 'Playlist From Final Project 3',
#   'owner': {'display_name': 'Muhammad Ramzy',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/ramzjet'},
#    'href': 'https://api.spotify.com/v1/users/ramzjet',
#    'id': 'ramzjet',
#    'type': 'user',
#    'uri': 'spotify:user:ramzjet'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MSw2ZDA1NjNmMTQ1MjUxZjIzNTFiZmFmZGQzZjNhZDU4NmExYzRiNmQx',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/2yoeICv7TkSqnh220UMwIE/tracks',
#    'items': [],
#    'limit': 100,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 0},
#   'type': 'playlist',
# ...

# %%
url = "https://api.spotify.com/v1/users/ramzjet/playlists"
headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
data = ("{\"name\": \"Playlist From Final Project 4\"}")
r = requests.post(url, headers=headers, data = data)
parsed = json.loads(r.text)
playlist4 = [parsed]

# %%
playlist4
# Out:
# [{'collaborative': False,
#   'description': None,
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/6Buvk2gEbhZ4lJwlIQGUhE'},
#   'followers': {'href': None, 'total': 0},
#   'href': 'https://api.spotify.com/v1/playlists/6Buvk2gEbhZ4lJwlIQGUhE',
#   'id': '6Buvk2gEbhZ4lJwlIQGUhE',
#   'images': [],
#   'name': 'Playlist From Final Project 4',
#   'owner': {'display_name': 'Muhammad Ramzy',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/ramzjet'},
#    'href': 'https://api.spotify.com/v1/users/ramzjet',
#    'id': 'ramzjet',
#    'type': 'user',
#    'uri': 'spotify:user:ramzjet'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MSw0YjcxYjFiYmMxNjc3MGYwN2IxOWRmMzViYzdhZTA2YWQxMGQ3NTIz',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/6Buvk2gEbhZ4lJwlIQGUhE/tracks',
#    'items': [],
#    'limit': 100,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 0},
#   'type': 'playlist',
# ...

# %%
url = "https://api.spotify.com/v1/users/ramzjet/playlists"
headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
data = ("{\"name\": \"Playlist From Final Project 5\"}")
r = requests.post(url, headers=headers, data = data)
parsed = json.loads(r.text)
playlist5 = [parsed]

# %%
playlist5
# Out:
# [{'collaborative': False,
#   'description': None,
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/2HmaeG1YCp4fzvextlLepg'},
#   'followers': {'href': None, 'total': 0},
#   'href': 'https://api.spotify.com/v1/playlists/2HmaeG1YCp4fzvextlLepg',
#   'id': '2HmaeG1YCp4fzvextlLepg',
#   'images': [],
#   'name': 'Playlist From Final Project 5',
#   'owner': {'display_name': 'Muhammad Ramzy',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/ramzjet'},
#    'href': 'https://api.spotify.com/v1/users/ramzjet',
#    'id': 'ramzjet',
#    'type': 'user',
#    'uri': 'spotify:user:ramzjet'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MSxkZjA2YzViOGNlYjQyNmEyOGVjYjY2Y2I2YjU2MjNmYzA4ZWIyODlj',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/2HmaeG1YCp4fzvextlLepg/tracks',
#    'items': [],
#    'limit': 100,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 0},
#   'type': 'playlist',
# ...

# %%
url = "https://api.spotify.com/v1/users/ramzjet/playlists"
headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
data = ("{\"name\": \"Playlist From Final Project 6\"}")
r = requests.post(url, headers=headers, data = data)
parsed = json.loads(r.text)
playlist6 = [parsed]

# %%
playlist6
# Out:
# [{'collaborative': False,
#   'description': None,
#   'external_urls': {'spotify': 'https://open.spotify.com/playlist/4pdGZJ8j5GIcAkfkrtkm5H'},
#   'followers': {'href': None, 'total': 0},
#   'href': 'https://api.spotify.com/v1/playlists/4pdGZJ8j5GIcAkfkrtkm5H',
#   'id': '4pdGZJ8j5GIcAkfkrtkm5H',
#   'images': [],
#   'name': 'Playlist From Final Project 6',
#   'owner': {'display_name': 'Muhammad Ramzy',
#    'external_urls': {'spotify': 'https://open.spotify.com/user/ramzjet'},
#    'href': 'https://api.spotify.com/v1/users/ramzjet',
#    'id': 'ramzjet',
#    'type': 'user',
#    'uri': 'spotify:user:ramzjet'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': 'MSxkMTg1YTk5NjBmOWFkOTI5MTZjMzZkYjY5YzQxYTg0ZWUzNGFlNmZh',
#   'tracks': {'href': 'https://api.spotify.com/v1/playlists/4pdGZJ8j5GIcAkfkrtkm5H/tracks',
#    'items': [],
#    'limit': 100,
#    'next': None,
#    'offset': 0,
#    'previous': None,
#    'total': 0},
#   'type': 'playlist',
# ...

# %%
playlist = [playlist1[0], playlist2[0], playlist3[0], playlist4[0], playlist5[0], playlist6[0]]

# %%
new_playlist_1 = pd.read_csv('new_playlist_1.csv')
new_playlist_2 = pd.read_csv('new_playlist_2.csv')
new_playlist_3 = pd.read_csv('new_playlist_3.csv')
new_playlist_4 = pd.read_csv('new_playlist_4.csv')
new_playlist_5 = pd.read_csv('new_playlist_5.csv')
new_playlist_6 = pd.read_csv('new_playlist_6.csv')

# %%
new_playlist_1
# Out:
#     Unnamed: 0        artist_name  \
# 0            0               joan
# 1            1        Kim Tae Woo
# 2            2        Fleet Foxes
# 3            3               DAY6
# 4            4     SEKAI NO OWARI
# 5            5         Ra Ra Riot
# 6            6     Declan McKenna
# 7            7  Foster The People
# 8            8           The Fray
# 9            9      eleventwelfth
# 10          10       Miami Horror
# 11          11          Kim Wilde
# 12          12     The Cat Police
# 13          13  Alanis Morissette
# 14          14         Lower Dens
# 15          15              LOONA
# 16          16              B.A.P
# 17          17              APRIL
# 18          18         Polka Wars
# 19          19          Big Grams
# 20          20         rebelsuns.
# 21          21         Portishead
# 22          22          will.i.am
# 23          23           Flo Rida
# 24          24           Glaskaca
# 25          25         Miike Snow
# ...

# %%
playlist[0]['id']
# Out:
# '2evgGdaDagUHvDqhNNG7pM'

# %% [markdown]
# # Adding track into the playlist

# %%
for i in new_playlist_1['uri']:
    url = "https://api.spotify.com/v1/playlists/2evgGdaDagUHvDqhNNG7pM/tracks?uris={}".format(i.replace(':','%3A'))
    headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
    r = requests.post(url, headers=headers)
    parsed = json.loads(r.text)

# %%
playlist[1]['id']
# Out:
# '0vcZPqe7JOKqWOkRi62vid'

# %%
for i in new_playlist_2['uri']:
    url = "https://api.spotify.com/v1/playlists/0vcZPqe7JOKqWOkRi62vid/tracks?uris={}".format(i.replace(':','%3A'))
    headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
    r = requests.post(url, headers=headers)
    parsed = json.loads(r.text)

# %%
playlist[2]['id']
# Out:
# '2yoeICv7TkSqnh220UMwIE'

# %%
for i in new_playlist_3['uri']:
    url = "https://api.spotify.com/v1/playlists/2yoeICv7TkSqnh220UMwIE/tracks?uris={}".format(i.replace(':','%3A'))
    headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
    r = requests.post(url, headers=headers)
    parsed = json.loads(r.text)

# %%
playlist[3]['id']
# Out:
# '6Buvk2gEbhZ4lJwlIQGUhE'

# %%
for i in new_playlist_4['uri']:
    url = "https://api.spotify.com/v1/playlists/6Buvk2gEbhZ4lJwlIQGUhE/tracks?uris={}".format(i.replace(':','%3A'))
    headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
    r = requests.post(url, headers=headers)
    parsed = json.loads(r.text)

# %%
playlist[4]['id']
# Out:
# '2HmaeG1YCp4fzvextlLepg'

# %%
for i in new_playlist_5['uri']:
    url = "https://api.spotify.com/v1/playlists/2HmaeG1YCp4fzvextlLepg/tracks?uris={}".format(i.replace(':','%3A'))
    headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
    r = requests.post(url, headers=headers)
    parsed = json.loads(r.text)

# %%
playlist[5]['id']
# Out:
# '4pdGZJ8j5GIcAkfkrtkm5H'

# %%
for i in new_playlist_6['uri']:
    url = "https://api.spotify.com/v1/playlists/4pdGZJ8j5GIcAkfkrtkm5H/tracks?uris={}".format(i.replace(':','%3A'))
    headers = {'Authorization': "Bearer {}".format(TOKEN), 'Content-Type': 'application/json'}
    r = requests.post(url, headers=headers)
    parsed = json.loads(r.text)

# %%
new_playlist_6
# Out:
#     Unnamed: 0                  artist_name  \
# 0            0                        APRIL
# 1            1                        TVXQ!
# 2            2                  Ringo Starr
# 3            3                       Eagles
# 4            4               10,000 Maniacs
# 5            5                Local Natives
# 6            6               Peter Frampton
# 7            7  Tommy James & The Shondells
# 8            8                    Leo Sayer
# 9            9                        OK Go
# 10          10     Bachman-Turner Overdrive
# 11          11          Jet Age of Tomorrow
# 12          12            Animal Collective
# 13          13                    John Cale
# 14          14                         Joji
# 15          15        Melody's Echo Chamber
# 16          16                     Kindness
# 17          17                       U-KISS
# 18          18                      Wallows
# 19          19                      J Dilla
# ...
